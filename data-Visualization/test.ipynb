# %%
from matplotlib import pyplot as plt
from matplotlib import style
style.available()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-1dba262f091b> in <module>
#       1 from matplotlib import pyplot as plt
#       2 from matplotlib import style
# ----> 3 style.available()
#
# TypeError: 'list' object is not callable

# %%
style.available
# Out:
# ['bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark-palette',
#  'seaborn-dark',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'seaborn',
#  'Solarize_Light2',
#  'tableau-colorblind10',
#  '_classic_test']

# %%
x = [5, 8, 10]
y = [12, 16, 6]
x2 = [6, 9, 11]
y2 = [6, 15, 7]
plt.plot(x,y,'g',label='line one',linewidth='5')

# %%
x = [5, 8, 10]
y = [12, 16, 6]
x2 = [6, 9, 11]
y2 = [6, 15, 7]
plt.plot(x, y, 'g', label='line one', linewidth='5')
plt.plot(x1, y2, 'red', label='line two', linewidth='5')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-e58077b18ee0> in <module>
#       4 y2 = [6, 15, 7]
#       5 plt.plot(x, y, 'g', label='line one', linewidth='5')
# ----> 6 plt.plot(x1, y2, 'red', label='line two', linewidth='5')
#
# NameError: name 'x1' is not defined

# %%
x = [5, 8, 10]
y = [12, 16, 6]
x2 = [6, 9, 11]
y2 = [6, 15, 7]
plt.plot(x, y, 'g', label='line one', linewidth='5')
plt.plot(x1, y2, 'r', label='line two', linewidth='5')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-1169d4931137> in <module>
#       4 y2 = [6, 15, 7]
#       5 plt.plot(x, y, 'g', label='line one', linewidth='5')
# ----> 6 plt.plot(x1, y2, 'r', label='line two', linewidth='5')
#
# NameError: name 'x1' is not defined

# %%
x = [5, 8, 10]
y = [12, 16, 6]
x2 = [6, 9, 11]
y2 = [6, 15, 7]
plt.plot(x, y, 'g', label='line one', linewidth='5')
plt.plot(x2, y2, 'r', label='line two', linewidth='5')

# %%
plt.plot(x, y, 'g', label='line one', linewidth='5')
plt.plot(x2, y2, 'red', label='line two', linewidth='5')

# %%
plt.plot(x, y, 'green', label='line one', linewidth='5')
plt.plot(x2, y2, 'red', label='line two', linewidth='5')

# %%
plt.title("GGPLOT Styling")
plt.ylabel('y-axis')
plt.xlabel('x-label')
plt.plot(x, y, 'green', label='line one', linewidth='5')
plt.plot(x2, y2, 'red', label='line two', linewidth='5')

# %%
plt.title("GGPLOT Styling")
plt.ylabel('y-axis')
plt.xlabel('x-label')
plt.plot(x, y, 'green', label='line one', linewidth='5')
plt.plot(x2, y2, 'red', label='line two', linewidth='5')
plt.legend()
plt.grid(True, color='k')

# %%
plt.show()

# %%
plt.show()

# %%
plt.title("GGPLOT Styling")
plt.ylabel('y-axis')
plt.xlabel('x-label')
plt.plot(x, y, 'green', label='line one', linewidth='5')
plt.plot(x2, y2, 'red', label='line two', linewidth='5')
plt.legend()
plt.grid(True, color='k')
plt.show()

# %%
plt.bar([1, 3, 5, 7, 9], [5, 2, 7, 8, 2], lable='Bargraph 1')
plt.bar([2, 4, 6, 8, 10], [8, 6, 2, 5, 6], label='Bargraph 2')
plt.legend()
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.title('Bargraph example')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-25-ec2aea770f0e> in <module>
# ----> 1 plt.bar([1, 3, 5, 7, 9], [5, 2, 7, 8, 2], lable='Bargraph 1')
#       2 plt.bar([2, 4, 6, 8, 10], [8, 6, 2, 5, 6], label='Bargraph 2')
#       3 plt.legend()
#       4 plt.xlabel('x-axis')
#       5 plt.ylabel('y-axis')
#
# C:\Anaconda\Anaconda3\lib\site-packages\matplotlib\pyplot.py in bar(x, height, width, bottom, align, data, **kwargs)
#    2432     return gca().bar(
#    2433         x, height, width=width, bottom=bottom, align=align,
# -> 2434         **({"data": data} if data is not None else {}), **kwargs)
#    2435
#    2436
#
# C:\Anaconda\Anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1587     def inner(ax, *args, data=None, **kwargs):
#    1588         if data is None:
# -> 1589             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1590
#    1591         bound = new_sig.bind(ax, *args, **kwargs)
#
# C:\Anaconda\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py in bar(self, x, height, width, bottom, align, **kwargs)
#    2430                 label='_nolegend_',
#    2431                 )
# -> 2432             r.update(kwargs)
#    2433             r.get_path()._interpolation_steps = 100
#    2434             if orientation == 'vertical':
#
# C:\Anaconda\Anaconda3\lib\site-packages\matplotlib\artist.py in update(self, props)
#     955
#     956         with cbook._setattr_cm(self, eventson=False):
# --> 957             ret = [_update_property(self, k, v) for k, v in props.items()]
#     958
#     959         if len(ret):
#
# C:\Anaconda\Anaconda3\lib\site-packages\matplotlib\artist.py in <listcomp>(.0)
#     955
#     956         with cbook._setattr_cm(self, eventson=False):
# --> 957             ret = [_update_property(self, k, v) for k, v in props.items()]
#     958
#     959         if len(ret):
#
# C:\Anaconda\Anaconda3\lib\site-packages\matplotlib\artist.py in _update_property(self, k, v)
#     951                 if not callable(func):
#     952                     raise AttributeError('{!r} object has no property {!r}'
# --> 953                                          .format(type(self).__name__, k))
#     954                 return func(v)
#     955
#
# AttributeError: 'Rectangle' object has no property 'lable'

# %%
plt.bar([1, 3, 5, 7, 9], [5, 2, 7, 8, 2], lable='Bargraph 1')
plt.bar([2, 4, 6, 8, 10], [8, 6, 2, 5, 6], label='Bargraph 2')
plt.legend()
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.title('Bargraph example')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-26-ec2aea770f0e> in <module>
# ----> 1 plt.bar([1, 3, 5, 7, 9], [5, 2, 7, 8, 2], lable='Bargraph 1')
#       2 plt.bar([2, 4, 6, 8, 10], [8, 6, 2, 5, 6], label='Bargraph 2')
#       3 plt.legend()
#       4 plt.xlabel('x-axis')
#       5 plt.ylabel('y-axis')
#
# C:\Anaconda\Anaconda3\lib\site-packages\matplotlib\pyplot.py in bar(x, height, width, bottom, align, data, **kwargs)
#    2432     return gca().bar(
#    2433         x, height, width=width, bottom=bottom, align=align,
# -> 2434         **({"data": data} if data is not None else {}), **kwargs)
#    2435
#    2436
#
# C:\Anaconda\Anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1587     def inner(ax, *args, data=None, **kwargs):
#    1588         if data is None:
# -> 1589             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1590
#    1591         bound = new_sig.bind(ax, *args, **kwargs)
#
# C:\Anaconda\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py in bar(self, x, height, width, bottom, align, **kwargs)
#    2430                 label='_nolegend_',
#    2431                 )
# -> 2432             r.update(kwargs)
#    2433             r.get_path()._interpolation_steps = 100
#    2434             if orientation == 'vertical':
#
# C:\Anaconda\Anaconda3\lib\site-packages\matplotlib\artist.py in update(self, props)
#     955
#     956         with cbook._setattr_cm(self, eventson=False):
# --> 957             ret = [_update_property(self, k, v) for k, v in props.items()]
#     958
#     959         if len(ret):
#
# C:\Anaconda\Anaconda3\lib\site-packages\matplotlib\artist.py in <listcomp>(.0)
#     955
#     956         with cbook._setattr_cm(self, eventson=False):
# --> 957             ret = [_update_property(self, k, v) for k, v in props.items()]
#     958
#     959         if len(ret):
#
# C:\Anaconda\Anaconda3\lib\site-packages\matplotlib\artist.py in _update_property(self, k, v)
#     951                 if not callable(func):
#     952                     raise AttributeError('{!r} object has no property {!r}'
# --> 953                                          .format(type(self).__name__, k))
#     954                 return func(v)
#     955
#
# AttributeError: 'Rectangle' object has no property 'lable'

# %%
plt.bar([1, 3, 5, 7, 9], [5, 2, 7, 8, 2], label="Bargraph 1")
plt.bar([2, 4, 6, 8, 10], [8, 6, 2, 5, 6], label='Bargraph 2')
plt.legend()
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.title('Bargraph example')
plt.show()

# %%
plt.bar([1, 3, 5, 7, 9], [5, 2, 7, 8, 2],color='red', label="Bargraph 1")
plt.bar([2, 4, 6, 8, 10], [8, 6, 2, 5, 6], label='Bargraph 2')
plt.legend()
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.title('Bargraph example')
plt.show()

# %%
plt.bar([1, 3, 5, 7, 9], [5, 2, 7, 8, 2],color='red', label="Bargraph 1")
plt.bar([2, 4, 6, 8, 10], [8, 6, 2, 5, 6],color='green', label='Bargraph 2')
plt.legend()
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.title('Bargraph example')
plt.show()

# %%
plt.bar([1, 3, 5, 7, 9], [5, 2, 7, 8, 2], color='red', label="Bargraph 1")
plt.bar([2, 4, 6, 8, 10], [8, 6, 2, 5, 6], color='green', label='Bargraph 2')
plt.legend()
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.title('Bargraph example')
plt.grid(True, color='k')
plt.show()
